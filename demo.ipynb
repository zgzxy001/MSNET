# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !pip install msgpack_numpy
# !pip uninstall tqdm
# !pip install tqdm==4.30.0

# %%
# !sudo apt-get install libtcmalloc-minimal4
# !export LD_PRELOAD="/usr/lib/libtcmalloc_minimal.so.4"

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('/img/demo_1.jpg')
imgplot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Model prediction on images on input-img folder
#
# Please modify the sys.path.append() row in predict.py if you meet the tensorpack module not found error

# %%
# !python "/msnet/examples/msnet/predict.py" \
 --config MODE_FPN=True \
	--load "/msnet_model/model-7400" --input-img "/img/"\
  --output-img "/img_pred/"

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('/img_pred/demo_1.jpg')
imgplot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
